# %%
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# # Script to compress images
#
# Use the Image with half the size of the original image and compress using fixed compression rates
#
# Compression rate = 100 - quality

# %%
rates = [30, 60, 75, 80, 85, 90, 95]

# %%
def save_compressed(img, directory):
    for rate in rates:
        quality = 100 - rate
        print(quality)
        img.save("{}/{}.jpg".format(directory, rate), "JPEG", quality=quality)

# %%
face = Image.open("images/face/original/face_x2.jpg")

# %%
plt.imshow(face)
plt.show()

# %%
save_compressed(face, "images/face/compressed")
# Out:
# 70
# 40
# 25
# 20
# 15
# 10
# 5

# %%
face.save("{}/{}.jpg".format("images/face/compressed", "test"), "JPEG", quality=10)
